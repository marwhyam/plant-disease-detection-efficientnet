# %% [markdown]
# # **Stage 1 Data Exploration & Preprocessing**

# %%
#cell 1
import os
import pandas as pd

# Define the paths
base_path = '/kaggle/input/plantvillage'
dataset_path = '/kaggle/input/plantvillage/dataset'
test_path = '/kaggle/input/plantvillage/dataset/test'
train_path = '/kaggle/input/plantvillage/dataset/train'
validation_path = '/kaggle/input/plantvillage/dataset/validation'

# Function to count files in a directory and its subdirectories
def count_files(directory):
    file_count = 0
    class_counts = {}
    
    if os.path.exists(directory):
        for class_name in os.listdir(directory):
            class_dir = os.path.join(directory, class_name)
            if os.path.isdir(class_dir):
                num_files = len(os.listdir(class_dir))
                class_counts[class_name] = num_files
                file_count += num_files
    return file_count, class_counts

# Get counts for each directory
total_files, _ = count_files(dataset_path)
test_count, test_classes = count_files(test_path)
train_count, train_classes = count_files(train_path)
val_count, val_classes = count_files(validation_path)

# Create a summary DataFrame
summary = pd.DataFrame({
    'Directory': ['/kaggle/input/plantvillage', 
                 '/kaggle/input/plantvillage/dataset',
                 '/kaggle/input/plantvillage/dataset/train',
                 '/kaggle/input/plantvillage/dataset/test',
                 '/kaggle/input/plantvillage/dataset/validation'],
    'Exists': [os.path.exists(base_path),
              os.path.exists(dataset_path),
              os.path.exists(train_path),
              os.path.exists(test_path),
              os.path.exists(validation_path)],
    'Total Files': [len(os.listdir(base_path)) if os.path.exists(base_path) else 0,
                   total_files,
                   train_count,
                   test_count,
                   val_count],
    'Subdirectories': [len(os.listdir(base_path)) if os.path.exists(base_path) else 0,
                      len(os.listdir(dataset_path)) if os.path.exists(dataset_path) else 0,
                      len(train_classes),
                      len(test_classes),
                      len(val_classes)]
})

print("Dataset Structure Summary:")
print(summary)

# Show class distribution in each split
print("\nClass Distribution:")

def print_class_distribution(name, class_counts):
    print(f"\n{name} set ({sum(class_counts.values())} images):")
    for class_name, count in class_counts.items():
        print(f"  {class_name}: {count} images")

print_class_distribution("Training", train_classes)
print_class_distribution("Test", test_classes)
print_class_distribution("Validation", val_classes)
# Out:
# Dataset Structure Summary:
#                                        Directory  Exists  Total Files  \
# 0                     /kaggle/input/plantvillage    True            1
# 1             /kaggle/input/plantvillage/dataset    True           45
# 2       /kaggle/input/plantvillage/dataset/train    True        16504
# 3        /kaggle/input/plantvillage/dataset/test    True         2064
# 4  /kaggle/input/plantvillage/dataset/validation    True         2070
#
#    Subdirectories
# 0               1
# 1               3
# 2              15
# 3              15
# 4              15
#
# Class Distribution:
#
# Training set (16504 images):
#   Pepper__bell___Bacterial_spot: 797 images
#   Potato___healthy: 121 images
#   Tomato_Leaf_Mold: 761 images
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 2566 images
#   Tomato_Bacterial_spot: 1701 images
#   Tomato_Septoria_leaf_spot: 1416 images
#   Tomato_healthy: 1272 images
#   Tomato_Spider_mites_Two_spotted_spider_mite: 1340 images
#   Tomato_Early_blight: 800 images
#   Tomato__Target_Spot: 1123 images
#   Pepper__bell___healthy: 1182 images
#   Potato___Late_blight: 800 images
#   Tomato_Late_blight: 1527 images
#   Potato___Early_blight: 800 images
#   Tomato__Tomato_mosaic_virus: 298 images
#
# Test set (2064 images):
#   Pepper__bell___Bacterial_spot: 100 images
#   Potato___healthy: 15 images
#   Tomato_Leaf_Mold: 95 images
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 321 images
#   Tomato_Bacterial_spot: 213 images
#   Tomato_Septoria_leaf_spot: 177 images
#   Tomato_healthy: 159 images
#   Tomato_Spider_mites_Two_spotted_spider_mite: 168 images
#   Tomato_Early_blight: 100 images
#   Tomato__Target_Spot: 140 images
#   Pepper__bell___healthy: 148 images
#   Potato___Late_blight: 100 images
#   Tomato_Late_blight: 191 images
#   Potato___Early_blight: 100 images
#   Tomato__Tomato_mosaic_virus: 37 images
#
# Validation set (2070 images):
#   Pepper__bell___Bacterial_spot: 100 images
#   Potato___healthy: 16 images
#   Tomato_Leaf_Mold: 96 images
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 321 images
#   Tomato_Bacterial_spot: 213 images
#   Tomato_Septoria_leaf_spot: 178 images
#   Tomato_healthy: 160 images
#   Tomato_Spider_mites_Two_spotted_spider_mite: 168 images
#   Tomato_Early_blight: 100 images
#   Tomato__Target_Spot: 141 images
#   Pepper__bell___healthy: 148 images
#   Potato___Late_blight: 100 images
#   Tomato_Late_blight: 191 images
#   Potato___Early_blight: 100 images
#   Tomato__Tomato_mosaic_virus: 38 images

# %%
#cell 2
# A. Class Distribution Analysis


import matplotlib.pyplot as plt
import seaborn as sns

# Convert class counts to DataFrame
train_counts = pd.DataFrame.from_dict(train_classes, orient='index', columns=['Train'])
test_counts = pd.DataFrame.from_dict(test_classes, orient='index', columns=['Test'])
val_counts = pd.DataFrame.from_dict(val_classes, orient='index', columns=['Validation'])

# Combine into one DataFrame
class_distribution = pd.concat([train_counts, test_counts, val_counts], axis=1)
class_distribution['Total'] = class_distribution.sum(axis=1)

# Plot class distribution
plt.figure(figsize=(15, 8))
sns.barplot(x=class_distribution.index, y=class_distribution['Train'])
plt.title("Training Set Class Distribution")
plt.xticks(rotation=90)
plt.ylabel("Number of Images")
plt.show()

# %%
##Cell 3
# B. Image Dimension Analysis


from PIL import Image
import numpy as np

def analyze_image_dimensions(directory, sample_size=50):
    widths, heights = [], []
    
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        images = os.listdir(class_path)[:sample_size]
        
        for img_name in images:
            img_path = os.path.join(class_path, img_name)
            with Image.open(img_path) as img:
                widths.append(img.width)
                heights.append(img.height)
    
    return widths, heights

# Analyze training set dimensions
widths, heights = analyze_image_dimensions(train_path)

print(f"Average Width: {np.mean(widths):.0f}px")
print(f"Average Height: {np.mean(heights):.0f}px")
print(f"Min Dimensions: {min(widths)}x{min(heights)}")
print(f"Max Dimensions: {max(widths)}x{max(heights)}")

# Plot distribution
plt.figure(figsize=(10, 5))
sns.scatterplot(x=widths, y=heights, alpha=0.5)
plt.title("Image Dimensions Scatter Plot")
plt.xlabel("Width (px)")
plt.ylabel("Height (px)")
plt.show()
# Out:
# Average Width: 256px
# Average Height: 256px
# Min Dimensions: 256x256
# Max Dimensions: 256x256

# %%
# cell 4 
# C. Sample Image Visualization

def display_class_samples(class_name, n_samples=5):
    class_dir = os.path.join(train_path, class_name)
    sample_images = os.listdir(class_dir)[:n_samples]
    
    plt.figure(figsize=(15, 3))
    for i, img_name in enumerate(sample_images):
        img_path = os.path.join(class_dir, img_name)
        img = Image.open(img_path)
        
        plt.subplot(1, n_samples, i+1)
        plt.imshow(img)
        plt.title(f"{class_name}\n{img.size[0]}x{img.size[1]}")
        plt.axis('off')
    plt.show()

# Display samples from 3 classes
display_class_samples("Tomato__Tomato_YellowLeaf__Curl_Virus")
display_class_samples("Potato___healthy")
display_class_samples("Tomato_Leaf_Mold")

# %%
# cell 5 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

augmentation = ImageDataGenerator(
    rescale=1./255,            # Normalize pixel values
    rotation_range=20,         # Reduce rotation range from ±40 to ±20 degrees
    width_shift_range=0.2,     # Horizontal shift
    height_shift_range=0.2,    # Vertical shift
    shear_range=0.2,           # Shear transformations
    zoom_range=0.1,            # Reduce zoom range from 0.3 to 0.1
    horizontal_flip=True,      # Random flips
    vertical_flip=True,        # Useful for leaf images
    brightness_range=[0.8, 1.2], # Reduce brightness adjustment range
    fill_mode='reflect'        # Better than 'nearest' for leaves
)


# For validation/test (only normalization)
test_val_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# 2025-04-29 19:56:57.220423: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745956617.414960      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745956617.470149      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# cell 6 
from sklearn.utils import class_weight
import numpy as np

# Prepare training labels array
train_labels = []
for i, class_name in enumerate(sorted(train_classes.keys())):
    train_labels.extend([i] * train_classes[class_name])
train_labels = np.array(train_labels)

# Compute class weights
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_labels),
    y=train_labels
)

# Normalize the class weights between 1 and 2
max_weight = max(class_weights)
min_weight = min(class_weights)
class_weights = {i: (w - min_weight) / (max_weight - min_weight) + 1 for i, w in enumerate(class_weights)}

# Print class weights for verification
print("Class Weights (Higher = More emphasis on minority classes):")
for i, class_name in enumerate(sorted(train_classes.keys())): 
    print(f"{i}: {class_name:45} → weight: {class_weights[i]:.2f}")
# Out:
# Class Weights (Higher = More emphasis on minority classes):
# 0: Pepper__bell___Bacterial_spot                 → weight: 1.11
# 1: Pepper__bell___healthy                        → weight: 1.06
# 2: Potato___Early_blight                         → weight: 1.11
# 3: Potato___Late_blight                          → weight: 1.11
# 4: Potato___healthy                              → weight: 2.00
# 5: Tomato_Bacterial_spot                         → weight: 1.03
# 6: Tomato_Early_blight                           → weight: 1.11
# 7: Tomato_Late_blight                            → weight: 1.03
# 8: Tomato_Leaf_Mold                              → weight: 1.12
# 9: Tomato_Septoria_leaf_spot                     → weight: 1.04
# 10: Tomato_Spider_mites_Two_spotted_spider_mite   → weight: 1.05
# 11: Tomato__Target_Spot                           → weight: 1.06
# 12: Tomato__Tomato_YellowLeaf__Curl_Virus         → weight: 1.00
# 13: Tomato__Tomato_mosaic_virus                   → weight: 1.38
# 14: Tomato_healthy                                → weight: 1.05

# %%
# cell 7
batch_size = 32
target_size = (256, 256)

# Training generator with updated augmentation
train_generator = augmentation.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True  # Critical for augmentation
)

# Validation generator (no augmentation)
val_generator = test_val_datagen.flow_from_directory(
    validation_path,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # No need to shuffle validation data
)
# Out:
# Found 16504 images belonging to 15 classes.
# Found 2070 images belonging to 15 classes.

# %%
#cell 8 
import json

config = {
    'target_size': target_size,
    'batch_size': batch_size,
    'class_weights': class_weights,
    'class_indices': train_generator.class_indices,
    'augmentation_params': {
        'rotation_range': augmentation.rotation_range,
        'width_shift_range': augmentation.width_shift_range,
        'height_shift_range': augmentation.height_shift_range,
        'shear_range': augmentation.shear_range,
        'zoom_range': augmentation.zoom_range,
        'horizontal_flip': augmentation.horizontal_flip,
        'vertical_flip': augmentation.vertical_flip,
        'brightness_range': augmentation.brightness_range,
        'fill_mode': augmentation.fill_mode
    }
}

with open('preprocessing_config.json', 'w') as f:
    json.dump(config, f, indent=2)

# %%
# cell 9
print("\nData Preparation Summary:")
print(f"- Training samples: {train_generator.samples}")
print(f"- Validation samples: {val_generator.samples}")
print(f"- Class weights: {class_weights}")
print("\nNext step: Pass these to model.fit():")
print(f"model.fit(train_generator, validation_data=val_generator, class_weight=class_weights)")
# Out:
# Data Preparation Summary:
# - Training samples: 16504
# - Validation samples: 2070
# - Class weights: {0: 1.1098439187854248, 1: 1.0579462212672015, 2: 1.1092464212678936, 3: 1.1092464212678936, 4: 2.0, 5: 1.0251662380723958, 6: 1.1092464212678936, 7: 1.033673093586071, 8: 1.1173813381918636, 9: 1.0401921366099385, 10: 1.0452785153984678, 11: 1.0635906232757348, 12: 1.0, 13: 1.3766459422736443, 14: 1.050344690100449}
#
# Next step: Pass these to model.fit():
# model.fit(train_generator, validation_data=val_generator, class_weight=class_weights)

# %% [markdown]
# # **Stage 2 CNN training**

# %%
# Cell 1 — Imports & paths
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Cell 2 — Generators (with correct preprocessing)
target_size = (280,280)
batch_size  = 32

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=50,
    width_shift_range=0.3,
    height_shift_range=0.3,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=(0.6,1.4),
    fill_mode='reflect'
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(
    train_path, target_size=target_size,
    batch_size=batch_size, class_mode='categorical'
)
val_gen   = test_datagen.flow_from_directory(
    validation_path, target_size=target_size,
    batch_size=batch_size, class_mode='categorical'
)
test_gen  = test_datagen.flow_from_directory(
    test_path, target_size=target_size,
    batch_size=batch_size, class_mode='categorical', shuffle=False
)
# Out:
# Found 16504 images belonging to 15 classes.
# Found 2070 images belonging to 15 classes.
# Found 2064 images belonging to 15 classes.

# %%
# Cell 3 — Build the TL model
backbone = EfficientNetB0(
    weights='imagenet', include_top=False,
    input_shape=(*target_size,3)
)

x = GlobalAveragePooling2D()(backbone.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(15, activation='softmax')(x)

tl_model = Model(backbone.input, outputs)

# start with backbone frozen
for layer in backbone.layers:
    layer.trainable = False

tl_model.compile(
    optimizer=Adam(1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
tl_model.summary()
# Out:
# I0000 00:00:1745956639.948115      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 280, 280, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 280, 280, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 280, 280, 3)    │              7 │ rescaling[0][0]        │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_1 (Rescaling)   │ (None, 280, 280, 3)    │              0 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv_pad             │ (None, 281, 281, 3)    │              0 │ rescaling_1[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 140, 140, 32)   │            864 │ stem_conv_pad[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 140, 140, 32)   │            128 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 140, 140, 32)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_dwconv            │ (None, 140, 140, 32)   │            288 │ stem_activation[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_bn                │ (None, 140, 140, 32)   │            128 │ block1a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_activation        │ (None, 140, 140, 32)   │              0 │ block1a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_squeeze        │ (None, 32)             │              0 │ block1a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reshape        │ (None, 1, 1, 32)       │              0 │ block1a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reduce         │ (None, 1, 1, 8)        │            264 │ block1a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_expand         │ (None, 1, 1, 32)       │            288 │ block1a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_excite         │ (None, 140, 140, 32)   │              0 │ block1a_activation[0]… │
# │ (Multiply)                │                        │                │ block1a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 140, 140, 16)   │            512 │ block1a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 140, 140, 16)   │             64 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 140, 140, 96)   │          1,536 │ block1a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 140, 140, 96)   │            384 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 140, 140, 96)   │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv_pad        │ (None, 141, 141, 96)   │              0 │ block2a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv            │ (None, 70, 70, 96)     │            864 │ block2a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_bn                │ (None, 70, 70, 96)     │            384 │ block2a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_activation        │ (None, 70, 70, 96)     │              0 │ block2a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_squeeze        │ (None, 96)             │              0 │ block2a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reshape        │ (None, 1, 1, 96)       │              0 │ block2a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reduce         │ (None, 1, 1, 4)        │            388 │ block2a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_expand         │ (None, 1, 1, 96)       │            480 │ block2a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_excite         │ (None, 70, 70, 96)     │              0 │ block2a_activation[0]… │
# │ (Multiply)                │                        │                │ block2a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 70, 70, 24)     │          2,304 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 70, 70, 24)     │             96 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 70, 70, 144)    │          3,456 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 70, 70, 144)    │            576 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 70, 70, 144)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 70, 70, 144)    │          1,296 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 70, 70, 144)    │            576 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 70, 70, 144)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 144)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 70, 70, 144)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 70, 70, 24)     │          3,456 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 70, 70, 24)     │             96 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 70, 70, 24)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 70, 70, 24)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 70, 70, 144)    │          3,456 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 70, 70, 144)    │            576 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 70, 70, 144)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv_pad        │ (None, 73, 73, 144)    │              0 │ block3a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv            │ (None, 35, 35, 144)    │          3,600 │ block3a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_bn                │ (None, 35, 35, 144)    │            576 │ block3a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_activation        │ (None, 35, 35, 144)    │              0 │ block3a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_squeeze        │ (None, 144)            │              0 │ block3a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reshape        │ (None, 1, 1, 144)      │              0 │ block3a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reduce         │ (None, 1, 1, 6)        │            870 │ block3a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block3a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_excite         │ (None, 35, 35, 144)    │              0 │ block3a_activation[0]… │
# │ (Multiply)                │                        │                │ block3a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 35, 35, 40)     │          5,760 │ block3a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 35, 35, 40)     │            160 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 35, 35, 240)    │          9,600 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 35, 35, 240)    │            960 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 35, 35, 240)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_dwconv            │ (None, 35, 35, 240)    │          6,000 │ block3b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_bn                │ (None, 35, 35, 240)    │            960 │ block3b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_activation        │ (None, 35, 35, 240)    │              0 │ block3b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_squeeze        │ (None, 240)            │              0 │ block3b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reshape        │ (None, 1, 1, 240)      │              0 │ block3b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reduce         │ (None, 1, 1, 10)       │          2,410 │ block3b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_expand         │ (None, 1, 1, 240)      │          2,640 │ block3b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_excite         │ (None, 35, 35, 240)    │              0 │ block3b_activation[0]… │
# │ (Multiply)                │                        │                │ block3b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 35, 35, 40)     │          9,600 │ block3b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 35, 35, 40)     │            160 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 35, 35, 40)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 35, 35, 40)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 35, 35, 240)    │          9,600 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 35, 35, 240)    │            960 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 35, 35, 240)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv_pad        │ (None, 37, 37, 240)    │              0 │ block4a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv            │ (None, 18, 18, 240)    │          2,160 │ block4a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 18, 18, 240)    │            960 │ block4a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 18, 18, 240)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 240)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 240)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 10)       │          2,410 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 240)      │          2,640 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 18, 18, 240)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 18, 18, 80)     │         19,200 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 18, 18, 80)     │            320 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 18, 18, 480)    │         38,400 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 18, 18, 480)    │          1,920 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 18, 18, 480)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv            │ (None, 18, 18, 480)    │          4,320 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 18, 18, 480)    │          1,920 │ block4b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 18, 18, 480)    │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 480)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 480)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 20)       │          9,620 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 480)      │         10,080 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 18, 18, 480)    │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 18, 18, 80)     │         38,400 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 18, 18, 80)     │            320 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 18, 18, 80)     │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 18, 18, 80)     │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 18, 18, 480)    │         38,400 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 18, 18, 480)    │          1,920 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 18, 18, 480)    │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv            │ (None, 18, 18, 480)    │          4,320 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 18, 18, 480)    │          1,920 │ block4c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 18, 18, 480)    │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 480)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 480)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 20)       │          9,620 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 480)      │         10,080 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 18, 18, 480)    │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 18, 18, 80)     │         38,400 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 18, 18, 80)     │            320 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 18, 18, 80)     │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 18, 18, 80)     │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_conv       │ (None, 18, 18, 480)    │         38,400 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_bn         │ (None, 18, 18, 480)    │          1,920 │ block5a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_activation │ (None, 18, 18, 480)    │              0 │ block5a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_dwconv            │ (None, 18, 18, 480)    │         12,000 │ block5a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_bn                │ (None, 18, 18, 480)    │          1,920 │ block5a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_activation        │ (None, 18, 18, 480)    │              0 │ block5a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_squeeze        │ (None, 480)            │              0 │ block5a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reshape        │ (None, 1, 1, 480)      │              0 │ block5a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reduce         │ (None, 1, 1, 20)       │          9,620 │ block5a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_expand         │ (None, 1, 1, 480)      │         10,080 │ block5a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_excite         │ (None, 18, 18, 480)    │              0 │ block5a_activation[0]… │
# │ (Multiply)                │                        │                │ block5a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_conv      │ (None, 18, 18, 112)    │         53,760 │ block5a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_bn        │ (None, 18, 18, 112)    │            448 │ block5a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_conv       │ (None, 18, 18, 672)    │         75,264 │ block5a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_bn         │ (None, 18, 18, 672)    │          2,688 │ block5b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_activation │ (None, 18, 18, 672)    │              0 │ block5b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_dwconv            │ (None, 18, 18, 672)    │         16,800 │ block5b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_bn                │ (None, 18, 18, 672)    │          2,688 │ block5b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_activation        │ (None, 18, 18, 672)    │              0 │ block5b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_se_squeeze        │ (None, 672)            │              0 │ block5b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_se_reshape        │ (None, 1, 1, 672)      │              0 │ block5b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_se_reduce         │ (None, 1, 1, 28)       │         18,844 │ block5b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_se_expand         │ (None, 1, 1, 672)      │         19,488 │ block5b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_se_excite         │ (None, 18, 18, 672)    │              0 │ block5b_activation[0]… │
# │ (Multiply)                │                        │                │ block5b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_project_conv      │ (None, 18, 18, 112)    │         75,264 │ block5b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_project_bn        │ (None, 18, 18, 112)    │            448 │ block5b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_drop (Dropout)    │ (None, 18, 18, 112)    │              0 │ block5b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_add (Add)         │ (None, 18, 18, 112)    │              0 │ block5b_drop[0][0],    │
# │                           │                        │                │ block5a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_expand_conv       │ (None, 18, 18, 672)    │         75,264 │ block5b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_expand_bn         │ (None, 18, 18, 672)    │          2,688 │ block5c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_expand_activation │ (None, 18, 18, 672)    │              0 │ block5c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_dwconv            │ (None, 18, 18, 672)    │         16,800 │ block5c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_bn                │ (None, 18, 18, 672)    │          2,688 │ block5c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_activation        │ (None, 18, 18, 672)    │              0 │ block5c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_se_squeeze        │ (None, 672)            │              0 │ block5c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_se_reshape        │ (None, 1, 1, 672)      │              0 │ block5c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_se_reduce         │ (None, 1, 1, 28)       │         18,844 │ block5c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_se_expand         │ (None, 1, 1, 672)      │         19,488 │ block5c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_se_excite         │ (None, 18, 18, 672)    │              0 │ block5c_activation[0]… │
# │ (Multiply)                │                        │                │ block5c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_project_conv      │ (None, 18, 18, 112)    │         75,264 │ block5c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_project_bn        │ (None, 18, 18, 112)    │            448 │ block5c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_drop (Dropout)    │ (None, 18, 18, 112)    │              0 │ block5c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5c_add (Add)         │ (None, 18, 18, 112)    │              0 │ block5c_drop[0][0],    │
# │                           │                        │                │ block5b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6a_expand_conv       │ (None, 18, 18, 672)    │         75,264 │ block5c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6a_expand_bn         │ (None, 18, 18, 672)    │          2,688 │ block6a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6a_expand_activation │ (None, 18, 18, 672)    │              0 │ block6a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ...
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6b_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block6b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6b_se_excite         │ (None, 9, 9, 1152)     │              0 │ block6b_activation[0]… │
# │ (Multiply)                │                        │                │ block6b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6b_project_conv      │ (None, 9, 9, 192)      │        221,184 │ block6b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6b_project_bn        │ (None, 9, 9, 192)      │            768 │ block6b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6b_drop (Dropout)    │ (None, 9, 9, 192)      │              0 │ block6b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6b_add (Add)         │ (None, 9, 9, 192)      │              0 │ block6b_drop[0][0],    │
# │                           │                        │                │ block6a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_expand_conv       │ (None, 9, 9, 1152)     │        221,184 │ block6b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_expand_bn         │ (None, 9, 9, 1152)     │          4,608 │ block6c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_expand_activation │ (None, 9, 9, 1152)     │              0 │ block6c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_dwconv            │ (None, 9, 9, 1152)     │         28,800 │ block6c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_bn                │ (None, 9, 9, 1152)     │          4,608 │ block6c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_activation        │ (None, 9, 9, 1152)     │              0 │ block6c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_se_squeeze        │ (None, 1152)           │              0 │ block6c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_se_reshape        │ (None, 1, 1, 1152)     │              0 │ block6c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_se_reduce         │ (None, 1, 1, 48)       │         55,344 │ block6c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block6c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_se_excite         │ (None, 9, 9, 1152)     │              0 │ block6c_activation[0]… │
# │ (Multiply)                │                        │                │ block6c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_project_conv      │ (None, 9, 9, 192)      │        221,184 │ block6c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_project_bn        │ (None, 9, 9, 192)      │            768 │ block6c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_drop (Dropout)    │ (None, 9, 9, 192)      │              0 │ block6c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6c_add (Add)         │ (None, 9, 9, 192)      │              0 │ block6c_drop[0][0],    │
# │                           │                        │                │ block6b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_expand_conv       │ (None, 9, 9, 1152)     │        221,184 │ block6c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_expand_bn         │ (None, 9, 9, 1152)     │          4,608 │ block6d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_expand_activation │ (None, 9, 9, 1152)     │              0 │ block6d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_dwconv            │ (None, 9, 9, 1152)     │         28,800 │ block6d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_bn                │ (None, 9, 9, 1152)     │          4,608 │ block6d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_activation        │ (None, 9, 9, 1152)     │              0 │ block6d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_squeeze        │ (None, 1152)           │              0 │ block6d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_reshape        │ (None, 1, 1, 1152)     │              0 │ block6d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_reduce         │ (None, 1, 1, 48)       │         55,344 │ block6d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block6d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_excite         │ (None, 9, 9, 1152)     │              0 │ block6d_activation[0]… │
# │ (Multiply)                │                        │                │ block6d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_project_conv      │ (None, 9, 9, 192)      │        221,184 │ block6d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_project_bn        │ (None, 9, 9, 192)      │            768 │ block6d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_drop (Dropout)    │ (None, 9, 9, 192)      │              0 │ block6d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_add (Add)         │ (None, 9, 9, 192)      │              0 │ block6d_drop[0][0],    │
# │                           │                        │                │ block6c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_conv       │ (None, 9, 9, 1152)     │        221,184 │ block6d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_bn         │ (None, 9, 9, 1152)     │          4,608 │ block7a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_activation │ (None, 9, 9, 1152)     │              0 │ block7a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_dwconv            │ (None, 9, 9, 1152)     │         10,368 │ block7a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_bn                │ (None, 9, 9, 1152)     │          4,608 │ block7a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_activation        │ (None, 9, 9, 1152)     │              0 │ block7a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_squeeze        │ (None, 1152)           │              0 │ block7a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reshape        │ (None, 1, 1, 1152)     │              0 │ block7a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reduce         │ (None, 1, 1, 48)       │         55,344 │ block7a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block7a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_excite         │ (None, 9, 9, 1152)     │              0 │ block7a_activation[0]… │
# │ (Multiply)                │                        │                │ block7a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_conv      │ (None, 9, 9, 320)      │        368,640 │ block7a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_bn        │ (None, 9, 9, 320)      │          1,280 │ block7a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 9, 9, 1280)     │        409,600 │ block7a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 9, 9, 1280)     │          5,120 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 9, 9, 1280)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ top_activation[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 256)            │        327,936 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 15)             │          3,855 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,381,362 (16.71 MB)
#  Trainable params: 331,791 (1.27 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
# Cell 4 — Callbacks
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=4, restore_best_weights=True, verbose=1),
    ModelCheckpoint('best_transfer_model.keras', 
                    monitor='val_accuracy', save_best_only=True, verbose=1)
]

# %%
# Cell 5 — Train head only
history_head = tl_model.fit(
    train_gen, validation_data=val_gen,
    epochs=10, callbacks=callbacks, verbose=1
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745956677.578097     130 service.cc:148] XLA service 0x7f066c1144b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745956677.578984     130 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745956679.415744     130 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/516 ━━━━━━━━━━━━━━━━━━━━ 4:42:38 33s/step - accuracy: 0.0000e+00 - loss: 2.8957
# I0000 00:00:1745956689.161417     130 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.5711 - loss: 1.3598
# Epoch 1: val_accuracy improved from -inf to 0.86135, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 472s 853ms/step - accuracy: 0.5716 - loss: 1.3583 - val_accuracy: 0.8614 - val_loss: 0.4178
# Epoch 2/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.8022 - loss: 0.5845
# Epoch 2: val_accuracy improved from 0.86135 to 0.90870, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 316s 604ms/step - accuracy: 0.8022 - loss: 0.5843 - val_accuracy: 0.9087 - val_loss: 0.2991
# Epoch 3/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.8486 - loss: 0.4677
# Epoch 3: val_accuracy did not improve from 0.90870
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 311s 595ms/step - accuracy: 0.8486 - loss: 0.4677 - val_accuracy: 0.8957 - val_loss: 0.3072
# Epoch 4/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.8517 - loss: 0.4420
# Epoch 4: val_accuracy did not improve from 0.90870
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 313s 599ms/step - accuracy: 0.8517 - loss: 0.4420 - val_accuracy: 0.9048 - val_loss: 0.2722
# Epoch 5/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.8606 - loss: 0.4184
# Epoch 5: val_accuracy improved from 0.90870 to 0.93961, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 312s 597ms/step - accuracy: 0.8606 - loss: 0.4184 - val_accuracy: 0.9396 - val_loss: 0.1869
# Epoch 6/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.8704 - loss: 0.3819
# Epoch 6: val_accuracy did not improve from 0.93961
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 307s 587ms/step - accuracy: 0.8704 - loss: 0.3819 - val_accuracy: 0.9372 - val_loss: 0.1937
# Epoch 7/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.8690 - loss: 0.3746
# Epoch 7: val_accuracy did not improve from 0.93961
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 309s 590ms/step - accuracy: 0.8690 - loss: 0.3745 - val_accuracy: 0.9348 - val_loss: 0.1962
# Epoch 8/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.8787 - loss: 0.3498
# Epoch 8: val_accuracy did not improve from 0.93961
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 307s 587ms/step - accuracy: 0.8787 - loss: 0.3498 - val_accuracy: 0.9324 - val_loss: 0.1870
# Epoch 9/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.8928 - loss: 0.3295
# Epoch 9: val_accuracy improved from 0.93961 to 0.94251, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 305s 583ms/step - accuracy: 0.8928 - loss: 0.3295 - val_accuracy: 0.9425 - val_loss: 0.1729
# Epoch 10/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.8954 - loss: 0.3198
# Epoch 10: val_accuracy improved from 0.94251 to 0.95072, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 308s 589ms/step - accuracy: 0.8954 - loss: 0.3199 - val_accuracy: 0.9507 - val_loss: 0.1430
# Restoring model weights from the end of the best epoch: 10.

# %%
import matplotlib.pyplot as plt

for metric in ('accuracy','loss'):
    plt.plot(history_head.history[metric], label=f"train_{metric}")
    plt.plot(history_head.history[f"val_{metric}"], label=f"val_{metric}")
    plt.legend(); plt.title(metric); plt.show()

# %%
# Cell 6 — Unfreeze last 30 layers, fine-tune
for layer in backbone.layers[-30:]:
    layer.trainable = True

tl_model.compile(
    optimizer=Adam(5e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_ft1 = tl_model.fit(
    train_gen, validation_data=val_gen,
    epochs=10, callbacks=callbacks, verbose=1
)
# Out:
# Epoch 1/10
# E0000 00:00:1745960264.247429     129 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745960264.454726     129 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745960264.899212     129 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745960265.106393     129 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 429/516 ━━━━━━━━━━━━━━━━━━━━ 52s 600ms/step - accuracy: 0.7829 - loss: 0.6795
# E0000 00:00:1745960533.911795     132 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745960534.121320     132 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745960534.535836     132 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745960534.745408     132 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.7909 - loss: 0.6522
# Epoch 1: val_accuracy did not improve from 0.95072
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 372s 649ms/step - accuracy: 0.7909 - loss: 0.6519 - val_accuracy: 0.9488 - val_loss: 0.1542
# Epoch 2/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.8861 - loss: 0.3358
# Epoch 2: val_accuracy improved from 0.95072 to 0.96039, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 306s 586ms/step - accuracy: 0.8861 - loss: 0.3358 - val_accuracy: 0.9604 - val_loss: 0.1170
# Epoch 3/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.9032 - loss: 0.2911
# Epoch 3: val_accuracy improved from 0.96039 to 0.96667, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 308s 589ms/step - accuracy: 0.9032 - loss: 0.2911 - val_accuracy: 0.9667 - val_loss: 0.1032
# Epoch 4/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.9179 - loss: 0.2391
# Epoch 4: val_accuracy improved from 0.96667 to 0.97101, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 305s 584ms/step - accuracy: 0.9179 - loss: 0.2391 - val_accuracy: 0.9710 - val_loss: 0.0879
# Epoch 5/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.9265 - loss: 0.2121
# Epoch 5: val_accuracy improved from 0.97101 to 0.97681, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 305s 583ms/step - accuracy: 0.9265 - loss: 0.2121 - val_accuracy: 0.9768 - val_loss: 0.0791
# Epoch 6/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.9256 - loss: 0.2102
# Epoch 6: val_accuracy did not improve from 0.97681
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 308s 589ms/step - accuracy: 0.9256 - loss: 0.2102 - val_accuracy: 0.9734 - val_loss: 0.0791
# Epoch 7/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.9429 - loss: 0.1753
# Epoch 7: val_accuracy improved from 0.97681 to 0.97778, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 308s 588ms/step - accuracy: 0.9429 - loss: 0.1753 - val_accuracy: 0.9778 - val_loss: 0.0701
# Epoch 8/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.9410 - loss: 0.1718
# Epoch 8: val_accuracy did not improve from 0.97778
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 305s 583ms/step - accuracy: 0.9410 - loss: 0.1718 - val_accuracy: 0.9768 - val_loss: 0.0647
# Epoch 9/10
# 515/516 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - accuracy: 0.9513 - loss: 0.1486
# Epoch 9: val_accuracy improved from 0.97778 to 0.97923, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 316s 604ms/step - accuracy: 0.9513 - loss: 0.1486 - val_accuracy: 0.9792 - val_loss: 0.0614
# Epoch 10/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.9508 - loss: 0.1517
# Epoch 10: val_accuracy improved from 0.97923 to 0.98068, saving model to best_transfer_model.keras
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 307s 587ms/step - accuracy: 0.9508 - loss: 0.1517 - val_accuracy: 0.9807 - val_loss: 0.0657
# Restoring model weights from the end of the best epoch: 10.

# %%
# Cell 7 — Unfreeze all, final fine-tuning
for layer in tl_model.layers:
    layer.trainable = True

tl_model.compile(
    optimizer=Adam(1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_ft2 = tl_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.8716 - loss: 0.4014
# Epoch 1: val_accuracy did not improve from 0.98068
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 439s 689ms/step - accuracy: 0.8716 - loss: 0.4014 - val_accuracy: 0.9343 - val_loss: 0.2102
# Epoch 2/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.8759 - loss: 0.3718
# Epoch 2: val_accuracy did not improve from 0.98068
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 311s 595ms/step - accuracy: 0.8759 - loss: 0.3718 - val_accuracy: 0.9353 - val_loss: 0.1995
# Epoch 3/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.8737 - loss: 0.3815
# Epoch 3: val_accuracy did not improve from 0.98068
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 308s 588ms/step - accuracy: 0.8737 - loss: 0.3815 - val_accuracy: 0.9415 - val_loss: 0.1845
# Epoch 4/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.8825 - loss: 0.3554
# Epoch 4: val_accuracy did not improve from 0.98068
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 309s 591ms/step - accuracy: 0.8825 - loss: 0.3554 - val_accuracy: 0.9440 - val_loss: 0.1790
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
# Cell 8 — Evaluate
print("Val  Accuracy:", max(history_ft2.history['val_accuracy']))
test_loss, test_acc = tl_model.evaluate(test_gen, verbose=1)[:2]
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Val  Accuracy: 0.9439613819122314
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 31s 477ms/step - accuracy: 0.9265 - loss: 0.2169
# Test Accuracy: 0.9162

# %%
# ─── Cell 9 — Save the Best & Final Models ─────────────────────────────────────

# You already have a ModelCheckpoint('best_transfer_model.keras') callback,
# so the best weights (by val_accuracy) are in best_transfer_model.keras.

# But let’s be explicit:

# 1) Save the best‐so‐far (already written by the callback):
#    best_transfer_model.keras

# 2) After all fine‐tuning, save your final weights:
tl_model.save('/kaggle/working/final_transfer_model.keras')
print("✅ Final transfer model saved to /kaggle/working/final_transfer_model.keras")

# Optional legacy H5:
tl_model.save('/kaggle/working/final_transfer_model.h5')
# Out:
# ✅ Final transfer model saved to /kaggle/working/final_transfer_model.keras

# %%
# ─── Cell 10 — Plot Training Curves ────────────────────────────────────────────

import matplotlib.pyplot as plt

def plot_history(hist, title_suffix=""):
    # accuracy
    plt.figure(figsize=(8,4))
    plt.plot(hist.history['accuracy'],     label='train acc')
    plt.plot(hist.history['val_accuracy'], label='val acc')
    plt.title(f'Accuracy over Epochs {title_suffix}')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy')
    plt.legend(); plt.show()
    
    # loss
    plt.figure(figsize=(8,4))
    plt.plot(hist.history['loss'],     label='train loss')
    plt.plot(hist.history['val_loss'], label='val loss')
    plt.title(f'Loss over Epochs {title_suffix}')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.legend(); plt.show()

# Plot each phase if you kept their histories:
plot_history(history_head, "— Head Only")
plot_history(history_ft1, "— Partial Fine-Tune")
plot_history(history_ft2, "— Full Fine-Tune")

# %%
# ─── Cell 11 — Final Evaluation & Confusion Matrix ────────────────────────────

import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 1) Evaluate on test set and print whatever metrics are available
results = tl_model.evaluate(test_gen, verbose=1)
names   = tl_model.metrics_names  # e.g. ['loss','accuracy','precision','recall']
for name, val in zip(names, results):
    print(f"🔹 {name.capitalize():<10}: {val:.4f}")

# 2) Confusion matrix & classification report
y_prob = tl_model.predict(test_gen, verbose=1)
y_pred = np.argmax(y_prob, axis=1)
y_true = test_gen.classes
class_names = list(test_gen.class_indices.keys())

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Test Confusion Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9265 - loss: 0.2169
# 🔹 Loss      : 0.2507
# 🔹 Compile_metrics: 0.9162
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step
# Classification Report:
#
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.99      0.91      0.95       100
#                      Pepper__bell___healthy       0.88      0.99      0.93       148
#                       Potato___Early_blight       0.93      0.98      0.96       100
#                        Potato___Late_blight       0.92      1.00      0.96       100
#                            Potato___healthy       0.93      0.87      0.90        15
#                       Tomato_Bacterial_spot       0.98      0.91      0.94       213
#                         Tomato_Early_blight       0.91      0.71      0.80       100
#                          Tomato_Late_blight       0.86      0.97      0.91       191
#                            Tomato_Leaf_Mold       0.93      0.85      0.89        95
#                   Tomato_Septoria_leaf_spot       0.91      0.84      0.87       177
# Tomato_Spider_mites_Two_spotted_spider_mite       0.87      0.88      0.88       168
#                         Tomato__Target_Spot       0.79      0.94      0.86       140
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.99      0.97      0.98       321
#                 Tomato__Tomato_mosaic_virus       1.00      0.54      0.70        37
#                              Tomato_healthy       0.91      0.97      0.94       159
#
#                                    accuracy                           0.92      2064
#                                   macro avg       0.92      0.89      0.90      2064
#                                weighted avg       0.92      0.92      0.91      2064

# %%
test_gen = test_datagen.flow_from_directory(
    test_path,  # Path to your test data folder
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',  # or 'binary' depending on your task
    shuffle=False  # Important to not shuffle when evaluating
)
# Out:
# Found 2064 images belonging to 15 classes.

# %%
# Evaluate on the full test dataset
test_loss, test_acc = tl_model.evaluate(test_gen, verbose=1)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
#  2/65 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8828 - loss: 0.3316
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9265 - loss: 0.2169
# Test Loss: 0.2507
# Test Accuracy: 0.9162

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get the images and labels from the test set
test_images, test_labels = next(iter(test_gen))  # Get a batch from the generator

# Predict the labels for the batch
y_prob = tl_model.predict(test_images)
y_pred = np.argmax(y_prob, axis=1)  # Get predicted class indices

# Get the class names from the test generator
class_names = list(test_gen.class_indices.keys())

# Create lists to store images and labels to show
images_to_show = []
labels_to_show = []

# Loop through all classes and collect 10 images from each class
for class_idx, class_name in enumerate(class_names):
    # Find indices of images that belong to the current class
    class_image_indices = np.where(np.argmax(test_labels, axis=1) == class_idx)[0]  # Convert one-hot to index
    
    # Check if there are at least 10 images
    num_images = min(len(class_image_indices), 10)
    
    # Select up to 10 images of this class
    class_images = [test_images[i] for i in class_image_indices[:num_images]]
    class_labels = [test_labels[i] for i in class_image_indices[:num_images]]
    
    # Add them to the lists
    images_to_show.extend(class_images)
    labels_to_show.extend(class_labels)

# Display 10 test images with their predicted and true labels
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.ravel()

for i in np.arange(10):
    axes[i].imshow(images_to_show[i])
    
    # Convert one-hot encoding to class index for true labels
    true_label = np.argmax(labels_to_show[i])
    
    # Add padding between predicted and true labels
    axes[i].set_title(f"Pred: {class_names[y_pred[i]]}\nTrue: {class_names[true_label]}", 
                      fontsize=10, pad=15)
    
    axes[i].axis('off')

plt.subplots_adjust(wspace=1.0, hspace=1.0)  # Increase horizontal and vertical space between subplots
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize lists to store images and labels to show
images_to_show = []
labels_to_show = []

# Get the class names from the generator
class_names = list(test_gen.class_indices.keys())

# Loop through the generator
for class_idx, class_name in enumerate(class_names):
    # Iterate through the generator and fetch one image per class
    for i, (img_batch, label_batch) in enumerate(test_gen):
        if class_name in test_gen.class_indices:
            class_label = np.argmax(label_batch[0])  # Get the class index of the batch
            if class_label == class_idx:  # If the current image belongs to the current class
                images_to_show.append(img_batch[0])  # Store the image
                labels_to_show.append(label_batch[0])  # Store the label
                print(f"Class '{class_name}' selected image index: {i}")
                break  # Only fetch one image per class

# Now display the images
fig, axes = plt.subplots(3, 5, figsize=(15, 9))  # Adjusting for 15 classes
axes = axes.ravel()

for i in np.arange(len(images_to_show)):
    axes[i].imshow(images_to_show[i])
    
    # Convert one-hot encoding to class index for true labels
    true_label = np.argmax(labels_to_show[i])
    
    # Predict the label for the image
    y_prob = tl_model.predict(np.expand_dims(images_to_show[i], axis=0))  # Add batch dimension
    y_pred = np.argmax(y_prob, axis=1)

    # Add padding between predicted and true labels
    axes[i].set_title(f"Pred: {class_names[y_pred[0]]}\nTrue: {class_names[true_label]}", 
                      fontsize=10, pad=15)
    
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.7, hspace=0.7)  # Increase space between subplots
plt.show()
# Out:
# Class 'Pepper__bell___Bacterial_spot' selected image index: 42
# Class 'Pepper__bell___healthy' selected image index: 3
# Class 'Potato___Early_blight' selected image index: 3
# Class 'Potato___Late_blight' selected image index: 2
# Class 'Potato___healthy' selected image index: 2
# Class 'Tomato_Bacterial_spot' selected image index: 0
# Class 'Tomato_Early_blight' selected image index: 6
# Class 'Tomato_Late_blight' selected image index: 2
# Class 'Tomato_Leaf_Mold' selected image index: 5
# Class 'Tomato_Septoria_leaf_spot' selected image index: 2
# Class 'Tomato_Spider_mites_Two_spotted_spider_mite' selected image index: 4
# Class 'Tomato__Target_Spot' selected image index: 4
# Class 'Tomato__Tomato_YellowLeaf__Curl_Virus' selected image index: 4
# Class 'Tomato__Tomato_mosaic_virus' selected image index: 9
# Class 'Tomato_healthy' selected image index: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
import gradio as gr
import tensorflow as tf
import numpy as np
from PIL import Image
from tensorflow.keras.applications.efficientnet import preprocess_input

# Load Keras model
model = tf.keras.models.load_model("/kaggle/input/plantdetect/other/default/1/final_transfer_model (2).keras")

# Class names in training order
class_names = [
    'Pepper__bell___Bacterial_spot',
    'Pepper__bell___healthy',
    'Potato___Early_blight',
    'Potato___Late_blight',
    'Potato___healthy',
    'Tomato_Bacterial_spot',
    'Tomato_Early_blight',
    'Tomato_Late_blight',
    'Tomato_Leaf_Mold',
    'Tomato_Septoria_leaf_spot',
    'Tomato_Spider_mites_Two_spotted_spider_mite',
    'Tomato__Target_Spot',
    'Tomato__Tomato_YellowLeaf__Curl_Virus',
    'Tomato__Tomato_mosaic_virus',
    'Tomato_healthy'
]

# Preprocess function (EfficientNet-style)
def predict_plant_disease(img):
    img = img.convert("RGB").resize((280, 280))
    arr = np.array(img).astype(np.float32)
    arr = preprocess_input(arr)  # scale to [-1, 1]
    arr = np.expand_dims(arr, axis=0)

    pred = model.predict(arr, verbose=0)
    index = np.argmax(pred)
    confidence = float(np.max(pred)) * 100

    return f"{class_names[index]} ({confidence:.2f}%)"

# Gradio interface
interface = gr.Interface(
    fn=predict_plant_disease,
    inputs=gr.Image(type="pil"),
    outputs=gr.Textbox(),
    title="Plant Disease Detector",
    description="Upload a leaf image to detect plant disease using a Keras EfficientNet model."
)

interface.launch(debug=True)
